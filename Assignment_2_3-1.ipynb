# %% [markdown]
# 1. Importing the necesary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# 2. Loading the data set

# %%
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# 3. Understanding the data set

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #Check if there are null values in the data set

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# 3. Uncovering factors that lead to employee attrition

# %%
# (a) breakdown of distance from home by job role and attrition using Groupby() function.

# %%
# Select the columns "Attrition", "JobRole", and "DistanceFromHome" from the data frame
df = df[["Attrition", "JobRole", "DistanceFromHome"]]

# %%
df
# Out:
#      Attrition                    JobRole  DistanceFromHome
# 0          Yes            Sales Executive                 1
# 1           No         Research Scientist                 8
# 2          Yes      Laboratory Technician                 2
# 3           No         Research Scientist                 3
# 4           No      Laboratory Technician                 2
# ...        ...                        ...               ...
# 1465        No      Laboratory Technician                23
# 1466        No  Healthcare Representative                 6
# 1467        No     Manufacturing Director                 4
# 1468        No            Sales Executive                 2
# 1469        No      Laboratory Technician                 8
#
# [1470 rows x 3 columns]

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by distance using the describe function
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].describe()

# %%
dist_from_home_by_jrole_attrition
# Out:
#                                      count       mean        std  min    25%  \
# JobRole                   Attrition
# Healthcare Representative No         122.0   9.204918   7.989599  1.0   2.00
#                           Yes          9.0  17.666667   8.093207  2.0  14.00
# Human Resources           No          40.0   6.600000   6.934862  1.0   2.00
#                           Yes         12.0  13.416667   8.005207  1.0   7.50
# Laboratory Technician     No         197.0   9.329949   8.101887  1.0   2.00
#                           Yes         62.0   9.661290   8.036685  1.0   3.00
# Manager                   No          97.0   7.927835   8.223756  1.0   2.00
#                           Yes          5.0  10.000000  12.020815  2.0   2.00
# Manufacturing Director    No         135.0   9.533333   8.725328  1.0   2.00
#                           Yes         10.0   8.800000   7.955431  1.0   2.25
# Research Director         No          78.0   8.474359   7.589679  1.0   2.00
# ...

# %%
# Instead of the predefined statistics, you can use
# specific combinations of aggregating statistics for given columns can be defined using the DataFrame.agg() method:
# e.g df.agg({'age': ['min', 'max', 'median', 'skew'],
        
df.agg({'JobRole': ['min', 'max', 'median', 'skew'],
             'DistanceFromHome': ['min', 'max', 'median', 'mean'],
            'Attrition': ['min', 'max', 'median', 'mean']})
# Out:
#                           JobRole  DistanceFromHome Attrition
# min     Healthcare Representative          1.000000        No
# max          Sales Representative         29.000000       Yes
# median                        NaN          7.000000       NaN
# mean                          NaN          9.192517       NaN

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by mean distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].mean()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            9.204918
#                            Yes          17.666667
# Human Resources            No            6.600000
#                            Yes          13.416667
# Laboratory Technician      No            9.329949
#                            Yes           9.661290
# Manager                    No            7.927835
#                            Yes          10.000000
# Manufacturing Director     No            9.533333
#                            Yes           8.800000
# Research Director          No            8.474359
#                            Yes           7.000000
# Research Scientist         No            8.869388
#                            Yes           9.765957
# Sales Executive            No            9.026022
#                            Yes          12.649123
# Sales Representative       No            9.000000
#                            Yes           8.151515
# ...

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by median distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].median()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            7.0
#                            Yes          20.0
# Human Resources            No            3.5
#                            Yes          15.0
# Laboratory Technician      No            7.0
#                            Yes           7.0
# Manager                    No            4.0
#                            Yes           2.0
# Manufacturing Director     No            7.0
#                            Yes           7.5
# Research Director          No            7.0
#                            Yes           7.0
# Research Scientist         No            6.0
#                            Yes           8.0
# Sales Executive            No            7.0
#                            Yes          11.0
# Sales Representative       No            7.0
#                            Yes           7.0
# Name: DistanceFromHome, dtype: float64

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by minimum distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].min()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           1
#                            Yes          2
# Human Resources            No           1
#                            Yes          1
# Laboratory Technician      No           1
#                            Yes          1
# Manager                    No           1
#                            Yes          2
# Manufacturing Director     No           1
#                            Yes          1
# Research Director          No           1
#                            Yes          2
# Research Scientist         No           1
#                            Yes          1
# Sales Executive            No           1
#                            Yes          1
# Sales Representative       No           1
#                            Yes          1
# Name: DistanceFromHome, dtype: int64

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by maximum distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].max()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           29
#                            Yes          29
# Human Resources            No           26
#                            Yes          23
# Laboratory Technician      No           29
#                            Yes          29
# Manager                    No           29
#                            Yes          29
# Manufacturing Director     No           29
#                            Yes          23
# Research Director          No           28
#                            Yes          12
# Research Scientist         No           29
#                            Yes          29
# Sales Executive            No           29
#                            Yes          29
# Sales Representative       No           29
#                            Yes          24
# Name: DistanceFromHome, dtype: int64

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by the variance of distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].var()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            63.833695
#                            Yes           65.500000
# Human Resources            No            48.092308
#                            Yes           64.083333
# Laboratory Technician      No            65.640578
#                            Yes           64.588313
# Manager                    No            67.630155
#                            Yes          144.500000
# Manufacturing Director     No            76.131343
#                            Yes           63.288889
# Research Director          No            57.603230
#                            Yes           50.000000
# Research Scientist         No            65.155002
#                            Yes           69.313599
# Sales Executive            No            60.935887
#                            Yes           79.696115
# Sales Representative       No            58.163265
#                            Yes           53.570076
# ...

# %%
# Group the data frame by "Attrition" and "JobRole, aggregated by the standard deviation of distance"
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].std()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            7.989599
#                            Yes           8.093207
# Human Resources            No            6.934862
#                            Yes           8.005207
# Laboratory Technician      No            8.101887
#                            Yes           8.036685
# Manager                    No            8.223756
#                            Yes          12.020815
# Manufacturing Director     No            8.725328
#                            Yes           7.955431
# Research Director          No            7.589679
#                            Yes           7.071068
# Research Scientist         No            8.071865
#                            Yes           8.325479
# Sales Executive            No            7.806144
#                            Yes           8.927268
# Sales Representative       No            7.626484
#                            Yes           7.319158
# ...

# %%
# (b) breakdown of average monthly income by education and attrition using Groupby()

# %%
# Select the columns "Attrition", "Education", and "MonthlyIncome" from the data frame
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

df = df[["Education", "Attrition", "MonthlyIncome"]]

# %%
df
# Out:
#       Education Attrition  MonthlyIncome
# 0             2       Yes           5993
# 1             1        No           5130
# 2             2       Yes           2090
# 3             4        No           2909
# 4             1        No           3468
# ...         ...       ...            ...
# 1465          2        No           2571
# 1466          1        No           9991
# 1467          3        No           6142
# 1468          3        No           5390
# 1469          3        No           4404
#
# [1470 rows x 3 columns]

# %%
# Group the data frame by "Attrition" and "Education", aggregated by "MonthlyIncome" using the describe function
mon_inc_by_educ_attrition = df.groupby(["Education", "Attrition"])["MonthlyIncome"].describe()

# %%
mon_inc_by_educ_attrition
# Out:
#                      count         mean          std     min      25%     50%  \
# Education Attrition
# 1         No         139.0  5926.129496  4557.227505  1052.0  2778.00  3977.0
#           Yes         31.0  4360.161290  3960.343302  1009.0  2384.50  3041.0
# 2         No         238.0  6586.058824  4729.373973  1051.0  3388.50  4998.5
#           Yes         44.0  4282.545455  2434.392255  1569.0  2362.25  2923.5
# 3         No         473.0  6882.919662  4890.265735  1200.0  2994.00  5210.0
#           Yes         99.0  4770.242424  4038.425873  1081.0  2307.50  2863.0
# 4         No         340.0  7087.814706  4776.846527  2001.0  3832.25  5463.5
#           Yes         58.0  5335.155172  3561.766026  1359.0  2742.25  4445.0
# 5         No          43.0  8559.906977  5188.329573  2127.0  4822.00  6272.0
#           Yes          5.0  5850.200000  3184.858113  2546.0  2956.00  6134.0
#
#                           75%      max
# Education Attrition
# ...

# %%
# Group the data frame by "Attrition" and "Education, aggregated by mean monthly Income"
mon_inc_by_educ_attrition = df.groupby(["Education", "Attrition"])["MonthlyIncome"].mean()

# %%
mon_inc_by_educ_attrition
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# 4. Data Visualisation

# %%
# Determine the relative frequency of workers leaving the organization by attrition
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.Attrition.value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %%
# 0.161224 of the workers, (16.1%) left the company compared to 0.838776 (83.9%) who stayed

# %%
# A bar chart comparing workers who stayed vs workers who left the company using pandas
df["Attrition"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Plotting bar chart using seaborn
sns.countplot(x = df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
# Pie chart comparing workers who stayed vs workers who left the company
df["Attrition"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
# Plotting the bar chart aggregating mean monthly income by education and attrition
df = mon_inc_by_educ_attrition

df
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %%
# The plot result
plt.figure(figsize=(10,8))
mon_inc_by_educ_attrition.plot(kind="bar", stacked=True)
plt.show()

# %%
# Plotting the barchart aggregating mean distance by Job Role and Attrition
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df = df[["Attrition", "JobRole", "DistanceFromHome"]]
dist_from_home_by_jrole_attrition = df.groupby(["JobRole", "Attrition"])["DistanceFromHome"].mean()

# %%
dist_from_home_by_jrole_attrition
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            9.204918
#                            Yes          17.666667
# Human Resources            No            6.600000
#                            Yes          13.416667
# Laboratory Technician      No            9.329949
#                            Yes           9.661290
# Manager                    No            7.927835
#                            Yes          10.000000
# Manufacturing Director     No            9.533333
#                            Yes           8.800000
# Research Director          No            8.474359
#                            Yes           7.000000
# Research Scientist         No            8.869388
#                            Yes           9.765957
# Sales Executive            No            9.026022
#                            Yes          12.649123
# Sales Representative       No            9.000000
#                            Yes           8.151515
# ...

# %%
# The plot result
plt.figure(figsize=(10,8))
dist_from_home_by_jrole_attrition.plot(kind="bar", stacked=True)
plt.show()
